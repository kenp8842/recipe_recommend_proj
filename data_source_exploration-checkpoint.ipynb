# %%
import pandas as pd
import json

#food.com data
df_food_com = pd.read_csv(r"C:\Users\kenp8\Downloads\RAW_recipes.csv")

# %% [markdown]
# The first set of data to take a look for the recipe recommending system at is from __[food.com](https://www.food.com/)__, source is __[here](https://www.kaggle.com/shuyangli94/food-com-recipes-and-user-interactions?select=RAW_recipes.csv)__. This set gives a good quantity with over 200k recipes from 18 years of recipes, as well as a description column that gives a little story element.

# %%
df_food_com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            231636 non-null  object
#  1   id              231637 non-null  int64
#  2   minutes         231637 non-null  int64
#  3   contributor_id  231637 non-null  int64
#  4   submitted       231637 non-null  object
#  5   tags            231637 non-null  object
#  6   nutrition       231637 non-null  object
#  7   n_steps         231637 non-null  int64
#  8   steps           231637 non-null  object
#  9   description     226658 non-null  object
#  10  ingredients     231637 non-null  object
#  11  n_ingredients   231637 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 21.2+ MB

# %%
df_food_com.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# ...

# %% [markdown]
# The next 3 sets all come from a single source, available __[here](https://eightportions.com/datasets/Recipes/)__ . They were scraped from __[Allrecipes.com](https://www.allrecipes.com/)__, __[Epicurious.com](https://www.epicurious.com/)__ and __[Foodnetwork.com](https://www.foodnetwork.com/)__. They provide a good amount of recipes and instructions but no descriptions were provided with this data.

# %%
#allrecipes data
df_ar = pd.read_json(r"C:\Users\kenp8\Downloads\recipes_raw_nosource_ar.json")

# %%
df_ar = df_ar.T
df_ar.tail()
# Out:
#                                                                   title  \
# gehEOcDPtU3SmNSXrwWwWD4ulPpUdMO                 Thai-Indian Veggie Soup
# VRAsyF.1xMBYqAVKX1biyIORH6N6qzy  Coconut Milk-Free Panang Curry Chicken
# Lf8/u.0k2029QMSQFrHS4gRsvKOQFUG                       Cooked Cold Salad
# ay.AqX/9ysBtWHcnHoDeGAyJ5Orla8e                Easy Eggnog Creme Brulee
# 2Q3Zpfgt/PUwn1YABjJ5A9T3ZW8xwVa            Super Power Stovetop Granola
#
#                                                                        ingredients  \
# gehEOcDPtU3SmNSXrwWwWD4ulPpUdMO  [2 teaspoons olive oil ADVERTISEMENT, 1/4 cup ...
# VRAsyF.1xMBYqAVKX1biyIORH6N6qzy  [2 cups light cream ADVERTISEMENT, 1/4 teaspoo...
# Lf8/u.0k2029QMSQFrHS4gRsvKOQFUG  [3 tablespoons bacon grease ADVERTISEMENT, 2 c...
# ay.AqX/9ysBtWHcnHoDeGAyJ5Orla8e  [4 egg yolks ADVERTISEMENT, 1 tablespoon white...
# 2Q3Zpfgt/PUwn1YABjJ5A9T3ZW8xwVa  [1/4 cup canola oil ADVERTISEMENT, 3 cups quic...
#
# ...

# %%
df_ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39802 entries, rmK12Uau.ntP510KeImX506H6Mr6jTu to 2Q3Zpfgt/PUwn1YABjJ5A9T3ZW8xwVa
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         39522 non-null  object
#  1   ingredients   39522 non-null  object
#  2   instructions  39522 non-null  object
#  3   picture_link  39522 non-null  object
# dtypes: object(4)
# memory usage: 2.8+ MB

# %%
#cleaning up missing info and getting index into better form
df_ar = df_ar.dropna(subset=['title'])
df_ar = df_ar.reset_index()
df_ar = df_ar.rename(columns = {'index': 'link'})
df_ar.tail()
# Out:
#                                   link  \
# 39517  gehEOcDPtU3SmNSXrwWwWD4ulPpUdMO
# 39518  VRAsyF.1xMBYqAVKX1biyIORH6N6qzy
# 39519  Lf8/u.0k2029QMSQFrHS4gRsvKOQFUG
# 39520  ay.AqX/9ysBtWHcnHoDeGAyJ5Orla8e
# 39521  2Q3Zpfgt/PUwn1YABjJ5A9T3ZW8xwVa
#
#                                         title  \
# 39517                 Thai-Indian Veggie Soup
# 39518  Coconut Milk-Free Panang Curry Chicken
# 39519                       Cooked Cold Salad
# 39520                Easy Eggnog Creme Brulee
# 39521            Super Power Stovetop Granola
#
#                                              ingredients  \
# 39517  [2 teaspoons olive oil ADVERTISEMENT, 1/4 cup ...
# 39518  [2 cups light cream ADVERTISEMENT, 1/4 teaspoo...
# 39519  [3 tablespoons bacon grease ADVERTISEMENT, 2 c...
# 39520  [4 egg yolks ADVERTISEMENT, 1 tablespoon white...
# 39521  [1/4 cup canola oil ADVERTISEMENT, 3 cups quic...
#
#                                             instructions  \
# ...

# %%
df_ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39522 entries, 0 to 39521
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   link          39522 non-null  object
#  1   title         39522 non-null  object
#  2   ingredients   39522 non-null  object
#  3   instructions  39522 non-null  object
#  4   picture_link  39522 non-null  object
# dtypes: object(5)
# memory usage: 1.5+ MB

# %%
#epicurious.com data
df_epi = pd.read_json(r"C:\Users\kenp8\Downloads\recipes_raw_nosource_epi.json")

# %%
#cleaning up missing info and getting index into better form
df_epi = df_epi.T
df_epi = df_epi.dropna(subset=['title'])
df_epi = df_epi.reset_index()
df_epi = df_epi.rename(columns = {'index': 'link'})
df_epi.tail()
# Out:
#                                   link  \
# 25318  lgygAJbdT1RNgrOYYveXtW4Ze9GtcZK
# 25319  EgIvlp1EfF4qTsnSI3v7ViZF1b3f2qC
# 25320  aCaoP.P8A1h6ALQmBnw3ypvYfRt/zZe
# 25321  fGxd/ZNUQcXxxqaVgEtMJmsNKLbugAe
# 25322  qznqHiNpq0AB1AYn002A2HvaEFnN0lq
#
#                                              ingredients  \
# 25318  [5 cups (about) canned beef broth, 1 cup lenti...
# 25319  [1/2 teaspoon turmeric, 2 cups water, 3/4 poun...
# 25320  [1 medium jalapeño, thinly sliced, 2 garlic cl...
# 25321  [1 1/2 cups almond flour or almond meal, 1/2 c...
# 25322  [1 1/2 pounds plum tomatoes, coarsely chopped ...
#
#                           picture_link  \
# 25318                             None
# 25319  16DvpBiksnvbWPCSdZUcPY3oFvgo0py
# 25320  m6IALrfAOr5KDVpqKcvUNpa7VermSIq
# 25321  wq1Cqtl16W8QpuFaXrDdB2kGsUn9Ku6
# 25322  DIZQ16bhYvwR7yKtaNOQf3XkgD0vbCK
#
#                                             instructions  \
# 25318  Bring 4 cups broth and lentils to boil in larg...
# ...

# %%
df_epi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25323 entries, 0 to 25322
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   link          25323 non-null  object
#  1   ingredients   25323 non-null  object
#  2   picture_link  12119 non-null  object
#  3   instructions  25323 non-null  object
#  4   title         25323 non-null  object
# dtypes: object(5)
# memory usage: 989.3+ KB

# %%
#foodnetwork.com data
df_fn = pd.read_json(r"C:\Users\kenp8\Downloads\recipes_raw_nosource_fn.json")

# %%
#cleaning up missing info and getting index into better form
df_fn = df_fn.T
df_fn = df_fn.dropna(subset=['title'])
df_fn = df_fn.reset_index()
df_fn = df_fn.rename(columns = {'index': 'link'})
df_fn.tail()
# Out:
#                                   link  \
# 59745  4bfMWxlbKhx/McJq/89k0SBdw.VvAzW
# 59746  T8lWBA1fcVdjxhMSWuoAbGoy5Lj.A8m
# 59747  f/coffo2TMs2J2gq5nTOUIqH2TRAkui
# 59748  q3aDJc4zoEF5QT4e7Mn.ieQwV.DyHwS
# 59749  7cXA77UpdDtIfBug2v6lEVIuV3Zcvhm
#
#                                             instructions  \
# 59745  Watch how to make this recipe.\nPreheat a gril...
# 59746  Preheat the broiler. Cut the tomatoes in 1/2 c...
# 59747  Heat the oil and butter in a large skillet ove...
# 59748  Preheat oven to 350 degrees. On the top half o...
# 59749  Watch how to make this recipe.\nIn a medium sa...
#
#                                              ingredients  \
# 59745  [4 ears fresh corn, 2 heads Belgian endive, 2 ...
# 59746  [4 large plum tomatoes, Salt and sugar, 1 1/2 ...
# 59747  [3 tablespoons olive oil, 2 tablespoons unsalt...
# 59748  [8 ounces butter, 8 ounces bittersweet chocola...
# 59749  [3 (10.5-ounce) cans restaurant-style condense...
#
# ...

# %%
df_fn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59750 entries, 0 to 59749
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   link          59750 non-null  object
#  1   instructions  59628 non-null  object
#  2   ingredients   59750 non-null  object
#  3   title         59750 non-null  object
#  4   picture_link  30952 non-null  object
# dtypes: object(5)
# memory usage: 2.3+ MB
